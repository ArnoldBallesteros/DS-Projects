# %%
import pandas as pd
import requests
from pytrends.request import TrendReq
import pygsheets
from bs4 import BeautifulSoup as bs
import pprint

# %%
gc = pygsheets.authorize(outh_file="D:\Documents\Projects\FIFA\client_secret.json")

# %%
kw_list = ["David De Gea","Manuel Neuer","Marc-Andre ter Stegen","Alisson","Keylor Navas"]
pytrend=TrendReq()
pytrend.build_payload(kw_list)
interest_over_time_df=pytrend.interest_over_time()
ts=pd.to_datetime(interest_over_time_df.index)
interest_over_time_df['date']=ts.strftime("%m.%d.%Y")
interest_over_time_df = interest_over_time_df.loc[interest_over_time_df['isPartial'] == 'False']
interest_over_time_df = interest_over_time_df[["date","David De Gea","Manuel Neuer","Marc-Andre ter Stegen","Alisson","Keylor Navas"]]

# %%
print(interest_over_time_df)
# Out:
#                   date  David De Gea  Manuel Neuer  Marc-Andre ter Stegen  \
# date
# 2013-06-09  06.09.2013             2             2                      0
# 2013-06-16  06.16.2013             3             2                      0
# 2013-06-23  06.23.2013             1             3                      0
# 2013-06-30  06.30.2013             1             1                      0
# 2013-07-07  07.07.2013             1             1                      0
# 2013-07-14  07.14.2013             1             1                      0
# 2013-07-21  07.21.2013             1             2                      0
# 2013-07-28  07.28.2013             1             2                      0
# 2013-08-04  08.04.2013             1             2                      0
# 2013-08-11  08.11.2013             1             2                      0
# 2013-08-18  08.18.2013             1             1                      0
# 2013-08-25  08.25.2013             1             3                      0
# 2013-09-01  09.01.2013             1             2                      0
# 2013-09-08  09.08.2013             1             1                      0
# 2013-09-15  09.15.2013             1             1                      0
# 2013-09-22  09.22.2013             1             1                      0
# 2013-09-29  09.29.2013             1             1                      0
# 2013-10-06  10.06.2013             1             2                      0
# 2013-10-13  10.13.2013             1             2                      0
# 2013-10-20  10.20.2013             1             1                      0
# 2013-10-27  10.27.2013             1             2                      0
# 2013-11-03  11.03.2013             1             1                      0
# 2013-11-10  11.10.2013             1             1                      0
# 2013-11-17  11.17.2013             1             2                      0
# 2013-11-24  11.24.2013             1             1                      0
# 2013-12-01  12.01.2013             1             2                      0
# 2013-12-08  12.08.2013             1             2                      0
# 2013-12-15  12.15.2013             1             2                      0
# 2013-12-22  12.22.2013             1             2                      0
# 2013-12-29  12.29.2013             1             1                      0
# ...                ...           ...           ...                    ...
# 2017-11-05  11.05.2017             2             3                      0
# 2017-11-12  11.12.2017             1             2                      0
# 2017-11-19  11.19.2017             1             2                      0
# 2017-11-26  11.26.2017             2             2                      0
# 2017-12-03  12.03.2017             5             4                      0
# 2017-12-10  12.10.2017             2             3                      0
# 2017-12-17  12.17.2017             1             2                      0
# 2017-12-24  12.24.2017             1             2                      0
# 2017-12-31  12.31.2017             1             2                      0
# 2018-01-07  01.07.2018             1             2                      0
# 2018-01-14  01.14.2018             1             2                      0
# 2018-01-21  01.21.2018             2             3                      0
# 2018-01-28  01.28.2018             2             2                      0
# 2018-02-04  02.04.2018             1             2                      0
# 2018-02-11  02.11.2018             1             3                      0
# 2018-02-18  02.18.2018             4             4                      0
# 2018-02-25  02.25.2018             2             2                      0
# 2018-03-04  03.04.2018             2             3                      0
# 2018-03-11  03.11.2018             2             3                      0
# 2018-03-18  03.18.2018             1             4                      0
# 2018-03-25  03.25.2018             2             5                      0
# 2018-04-01  04.01.2018             2             4                      0
# 2018-04-08  04.08.2018             2             4                      0
# 2018-04-15  04.15.2018             2             3                      0
# 2018-04-22  04.22.2018             2             7                      0
# 2018-04-29  04.29.2018             2             9                      0
# 2018-05-06  05.06.2018             2             5                      0
# 2018-05-13  05.13.2018             2             5                      0
# 2018-05-20  05.20.2018             1             4                      0
# 2018-05-27  05.27.2018             1             7                      0
#
#             Alisson  Keylor Navas
# date
# 2013-06-09        1             0
# 2013-06-16        2             0
# 2013-06-23        2             0
# 2013-06-30        2             0
# 2013-07-07        1             0
# 2013-07-14        2             0
# 2013-07-21        2             0
# 2013-07-28        2             0
# 2013-08-04        2             0
# 2013-08-11        2             0
# 2013-08-18        2             0
# 2013-08-25        2             0
# 2013-09-01        2             0
# 2013-09-08        2             0
# 2013-09-15        2             0
# 2013-09-22        2             0
# 2013-09-29        1             0
# 2013-10-06        2             0
# 2013-10-13        1             0
# 2013-10-20        2             0
# 2013-10-27        2             0
# 2013-11-03        2             0
# 2013-11-10        1             0
# 2013-11-17        1             0
# 2013-11-24        2             0
# 2013-12-01        1             0
# 2013-12-08        1             0
# 2013-12-15        1             0
# 2013-12-22        1             0
# 2013-12-29        1             0
# ...             ...           ...
# 2017-11-05        4             2
# 2017-11-12        4             2
# 2017-11-19        4             2
# 2017-11-26        4             2
# 2017-12-03        4             1
# 2017-12-10        4             2
# 2017-12-17        4             2
# 2017-12-24        4             2
# 2017-12-31        5             2
# 2018-01-07        5             2
# 2018-01-14        4             1
# 2018-01-21        5             1
# 2018-01-28        5             2
# 2018-02-04        4             1
# 2018-02-11        5             2
# 2018-02-18        6             2
# 2018-02-25        5             2
# 2018-03-04        5             2
# 2018-03-11        5             1
# 2018-03-18        7             2
# 2018-03-25        8             1
# 2018-04-01        7             4
# 2018-04-08        8             4
# 2018-04-15        5             2
# 2018-04-22        7             6
# 2018-04-29        6             8
# 2018-05-06        6             3
# 2018-05-13        6             2
# 2018-05-20        7             7
# 2018-05-27       10             6
#
# [260 rows x 6 columns]

# %%
interest_over_time_df2 = pd.melt(interest_over_time_df,id_vars=['date'], var_name=
'goalie_name',value_name='index')
print(interest_over_time_df2)
# Out:
#             date   goalie_name  index
# 0     06.09.2013  David De Gea      2
# 1     06.16.2013  David De Gea      3
# 2     06.23.2013  David De Gea      1
# 3     06.30.2013  David De Gea      1
# 4     07.07.2013  David De Gea      1
# 5     07.14.2013  David De Gea      1
# 6     07.21.2013  David De Gea      1
# 7     07.28.2013  David De Gea      1
# 8     08.04.2013  David De Gea      1
# 9     08.11.2013  David De Gea      1
# 10    08.18.2013  David De Gea      1
# 11    08.25.2013  David De Gea      1
# 12    09.01.2013  David De Gea      1
# 13    09.08.2013  David De Gea      1
# 14    09.15.2013  David De Gea      1
# 15    09.22.2013  David De Gea      1
# 16    09.29.2013  David De Gea      1
# 17    10.06.2013  David De Gea      1
# 18    10.13.2013  David De Gea      1
# 19    10.20.2013  David De Gea      1
# 20    10.27.2013  David De Gea      1
# 21    11.03.2013  David De Gea      1
# 22    11.10.2013  David De Gea      1
# 23    11.17.2013  David De Gea      1
# 24    11.24.2013  David De Gea      1
# 25    12.01.2013  David De Gea      1
# 26    12.08.2013  David De Gea      1
# 27    12.15.2013  David De Gea      1
# 28    12.22.2013  David De Gea      1
# 29    12.29.2013  David De Gea      1
# ...          ...           ...    ...
# 1270  11.05.2017  Keylor Navas      2
# 1271  11.12.2017  Keylor Navas      2
# 1272  11.19.2017  Keylor Navas      2
# 1273  11.26.2017  Keylor Navas      2
# 1274  12.03.2017  Keylor Navas      1
# 1275  12.10.2017  Keylor Navas      2
# 1276  12.17.2017  Keylor Navas      2
# 1277  12.24.2017  Keylor Navas      2
# 1278  12.31.2017  Keylor Navas      2
# 1279  01.07.2018  Keylor Navas      2
# 1280  01.14.2018  Keylor Navas      1
# 1281  01.21.2018  Keylor Navas      1
# 1282  01.28.2018  Keylor Navas      2
# 1283  02.04.2018  Keylor Navas      1
# 1284  02.11.2018  Keylor Navas      2
# 1285  02.18.2018  Keylor Navas      2
# 1286  02.25.2018  Keylor Navas      2
# 1287  03.04.2018  Keylor Navas      2
# 1288  03.11.2018  Keylor Navas      1
# 1289  03.18.2018  Keylor Navas      2
# 1290  03.25.2018  Keylor Navas      1
# 1291  04.01.2018  Keylor Navas      4
# 1292  04.08.2018  Keylor Navas      4
# 1293  04.15.2018  Keylor Navas      2
# 1294  04.22.2018  Keylor Navas      6
# 1295  04.29.2018  Keylor Navas      8
# 1296  05.06.2018  Keylor Navas      3
# 1297  05.13.2018  Keylor Navas      2
# 1298  05.20.2018  Keylor Navas      7
# 1299  05.27.2018  Keylor Navas      6
#
# [1300 rows x 3 columns]

# %%
sh=gc.open('Top FIFA Goalies')
wks = sh.worksheet_by_title("google_trends_data")

wks.set_dataframe(interest_over_time_df2,(1,1))

# %%
url='http://www.transfermarkt.com/detailsuche/spielerdetail/suche/9069756'
headers = {'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_11_6) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/61.0.3163.100 Safari/537.36'}
player_info = [[] for i in range(2)]
response=requests.get(url,headers=headers)
#response.status_code
soup = bs(response.content,"html.parser")
table = soup.find(class_='items')
for item in table.find_all('a',{'class':'spielprofil_tooltip'}):
    #print(item.get('title') + ':' + item.get('id'))
    player_info[0].append(item.get('title').replace(' ','-'))
    player_info[1].append(item.get('id'))

# %%
print(player_info[0])
# Out:
# ['Neymar', 'Lionel-Messi', 'Mohamed-Salah', 'Harry-Kane', 'Kylian-Mbappé', 'Eden-Hazard', 'Paulo-Dybala', 'Antoine-Griezmann', 'Philippe-Coutinho', 'Cristiano-Ronaldo', 'Leroy-Sané', 'Raheem-Sterling', 'Romelu-Lukaku', 'Gareth-Bale', 'Robert-Lewandowski', 'Gabriel-Jesus', 'Ousmane-Dembélé', 'Roberto-Firmino', 'Sergio-Agüero', 'Marco-Asensio', 'Mauro-Icardi', 'Pierre-Emerick-Aubameyang', 'Sadio-Mané', 'Luis-Suárez', 'Alexis-Sánchez']

# %%
player_response = requests.get("https://www.transfermarkt.com/"+ str(player_info[0][0])+ "/leistungsdatendetails/spieler/" + str(player_info[1][0]) + "/saison//verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1", headers = headers )
player_soup = bs(player_response.content,"html.parser")

player_headers = []
table = player_soup.find(class_='items')
for item in thead.find_all('a',{'class':'sort-link'}):
    #print(item.contents[0])
    if (str(type(item.contents[0])) == "<class 'bs4.element.NavigableString'>"):
        player_headers.append(item.contents[0])
    else:
        player_headers.append(item.contents[0].get('title'))

table_body = table.find('tbody')
rows = table_body.find_all('tr')

data = [[] for i in range(len(player_headers))]

for row in rows:
    i=0
    for element in row.find_all('td'):
        if (str(element.contents[0])[0]) == "<":
            if str(type(element.find('a'))) == "<class 'NoneType'>":
                1+1
            else:
                if str(element.find('a').contents[0])[0]=="<":
                    
                    data[i].append(str(element.find('a').get('href')).strip('/').split('/')[0])
                else:
                    
                    data[i].append(element.find('a').contents[0])
        else:
            data[i].append(element.contents[0])
        i=i+1
        
data.pop(1)
player_headers.pop(2)
player_df = pd.DataFrame(data)
player_df = player_df.transpose()
player_df.columns = player_headers
player_df
# Out:
#    Season          Competition                 Club(s) Squad Apps   PPM Goals  \
# 0   17/18              Ligue 1  fc-paris-saint-germain    20   20  2,75    19
# 1   17/18     Champions League  fc-paris-saint-germain     7    7  2,14     6
# 2   17/18    Coupe de la Ligue  fc-paris-saint-germain     2    2  3,00     1
# 3   17/18      Coupe de France  fc-paris-saint-germain     1    1  3,00     2
# 4   16/17         Copa del Rey            fc-barcelona     6    6  2,50     3
# 5   16/17               LaLiga            fc-barcelona    31   30  2,30    13
# 6   16/17     Champions League            fc-barcelona     9    9  1,78     4
# 7   15/16         Copa del Rey            fc-barcelona     7    5  3,00     4
# 8   15/16               LaLiga            fc-barcelona    34   34  2,38    24
# 9   15/16     Champions League            fc-barcelona     9    9  2,44     3
# 10  15/16       Club World Cup            fc-barcelona     2    1  3,00     -
# 11  14/15     Champions League            fc-barcelona    13   12  2,50    10
# 12  14/15         Copa del Rey            fc-barcelona     6    6  3,00     7
# 13  14/15               LaLiga            fc-barcelona    35   33  2,45    22
# 14  13/14               LaLiga            fc-barcelona    29   26  2,31     9
# 15  13/14         Copa del Rey            fc-barcelona     4    3  2,00     1
# 16  13/14     Champions League            fc-barcelona    10   10  2,00     4
# 17  13/14            Supercopa            fc-barcelona     2    2  1,00     1
# 18   2013              Série A               fc-santos     1    1  1,00     -
# 19   2012              Série A               fc-santos    17   17  1,88    14
# 20   2012  Recopa Sudamericana               fc-santos     2    2  2,00     1
# 21   2012         Libertadores               fc-santos    12   12  1,67     8
# 22  11/12       Club World Cup               fc-santos     2    2  1,50     1
# 23   2011              Série A               fc-santos    21   21  1,52    13
# 24   2011         Libertadores               fc-santos    13   13  1,85     6
# 25   2010              Série A               fc-santos    31   31  1,42    17
# 26   2010    Copa Sudamericana               fc-santos     2    2  1,50     -
# 27   2009              Série A               fc-santos    33   33  1,42    10
#
#    Assists own goals Substituted on Substituted off Yellow cards  \
# 0       14         -              -               -            4
# 1        3         -              -               -            2
# 2        -         -              -               -            1
# 3        -         -              -               -            -
# 4        3         -              -               2            3
# 5       15         -              -               2            7
# 6        9         -              -               1            5
# 7        2         -              -               -            2
# 8       17         -              -               1            6
# 9        5         -              -               -            2
# 10       2         -              -               1            1
# 11       -         -              -               3            1
# 12       1         -              -               2            1
# 13       9         -              4               9            6
# 14      10         -              7              11            6
# 15       -         -              -               1            1
# 16       5         -              1               5            1
# 17       -         -              1               -            1
# 18       -         -              -               -            -
# 19       7         -              -               -            6
# 20       -         -              -               -            -
# 21       3         -              -               -            6
# 22       -         -              -               -            -
# 23       5         -              -               1            8
# 24       3         -              -               -            5
# 25       9         -              -               8           11
# 26       1         -              1               -            1
# 27       7         -             19               8            6
#
#    Yellow/red cards Red cards Penalty goals Minutes per goal Minutes played
# 0                 1         -             4              95'         1.797'
# 1                 -         -             -             105'           630'
# 2                 -         -             1             180'           180'
# 3                 -         -             -              45'            90'
# 4                 -         -             2             174'           522'
# 5                 -         1             1             204'         2.653'
# 6                 -         -             1             199'           797'
# 7                 -         -             -             120'           480'
# 8                 -         -             5             127'         3.056'
# 9                 -         -             1             270'           810'
# 10                -         -             -                -            88'
# 11                -         -             -             103'         1.025'
# 12                -         -             -              72'           503'
# 13                -         -             1             117'         2.570'
# 14                -         -             1             193'         1.736'
# 15                -         -             -             206'           206'
# 16                -         -             -             194'           775'
# 17                -         -             -             121'           121'
# 18                -         -             -                -            90'
# 19                -         1             1             107'         1.493'
# 20                -         -             -             180'           180'
# 21                -         -             2             139'         1.110'
# 22                -         -             -             180'           180'
# 23                1         -             4             145'         1.882'
# 24                1         -             -             189'         1.133'
# 25                -         -             4             156'         2.654'
# 26                -         -             -                -           134'
# 27                -         -             -             162'         1.621'

# %%
frames={}
for x in range(len(player_info[0])):
    #player_url= "https://www.transfermarkt.com/"+ str(player_info[0][x])+ "/leistungsdatendetails/spieler/" + str(player_info[1][x])
    player_response = requests.get("https://www.transfermarkt.com/"+ str(player_info[0][x])+ "/leistungsdatendetails/spieler/" + str(player_info[1][x]) + "/saison//verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1", headers = headers )
    player_soup = bs(player_response.content,"html.parser")
    
    player_headers = []
    table = player_soup.find(class_='items')
    for item in thead.find_all('a',{'class':'sort-link'}):
        #print(item.contents[0])
        if str(type(item.contents[0])) == "<class 'bs4.element.NavigableString'>":
            player_headers.append(item.contents[0])
        else:
            player_headers.append(item.contents[0].get('title'))

    table_body = table.find('tbody')
    rows = table_body.find_all('tr')

    data = [[] for i in range(len(player_headers))]

    for row in rows:
        i=0
        for element in row.find_all('td'):
            if (str(element.contents[0])[0]) == "<":
                if str(type(element.find('a'))) == "<class 'NoneType'>":
                    1+1
                else:
                    if str(element.find('a').contents[0])[0]=="<":
                    
                        data[i].append(str(element.find('a').get('href')).strip('/').split('/')[0])
                    else:
                    
                        data[i].append(element.find('a').contents[0])
            else:
                data[i].append(element.contents[0])
            i=i+1
        
    data.pop(1)
    player_headers.pop(2)
    player_df = pd.DataFrame(data)
    player_df = player_df.transpose()
    player_df.columns = player_headers
    player_df
    frames[player_info[0][x]] = player_df

# %%
frames[player_info[0][0]]
# Out:
#    Season          Competition                 Club(s) Squad Apps   PPM Goals  \
# 0   17/18              Ligue 1  fc-paris-saint-germain    20   20  2,75    19
# 1   17/18     Champions League  fc-paris-saint-germain     7    7  2,14     6
# 2   17/18    Coupe de la Ligue  fc-paris-saint-germain     2    2  3,00     1
# 3   17/18      Coupe de France  fc-paris-saint-germain     1    1  3,00     2
# 4   16/17         Copa del Rey            fc-barcelona     6    6  2,50     3
# 5   16/17               LaLiga            fc-barcelona    31   30  2,30    13
# 6   16/17     Champions League            fc-barcelona     9    9  1,78     4
# 7   15/16         Copa del Rey            fc-barcelona     7    5  3,00     4
# 8   15/16               LaLiga            fc-barcelona    34   34  2,38    24
# 9   15/16     Champions League            fc-barcelona     9    9  2,44     3
# 10  15/16       Club World Cup            fc-barcelona     2    1  3,00     -
# 11  14/15     Champions League            fc-barcelona    13   12  2,50    10
# 12  14/15         Copa del Rey            fc-barcelona     6    6  3,00     7
# 13  14/15               LaLiga            fc-barcelona    35   33  2,45    22
# 14  13/14               LaLiga            fc-barcelona    29   26  2,31     9
# 15  13/14         Copa del Rey            fc-barcelona     4    3  2,00     1
# 16  13/14     Champions League            fc-barcelona    10   10  2,00     4
# 17  13/14            Supercopa            fc-barcelona     2    2  1,00     1
# 18   2013              Série A               fc-santos     1    1  1,00     -
# 19   2012              Série A               fc-santos    17   17  1,88    14
# 20   2012  Recopa Sudamericana               fc-santos     2    2  2,00     1
# 21   2012         Libertadores               fc-santos    12   12  1,67     8
# 22  11/12       Club World Cup               fc-santos     2    2  1,50     1
# 23   2011              Série A               fc-santos    21   21  1,52    13
# 24   2011         Libertadores               fc-santos    13   13  1,85     6
# 25   2010              Série A               fc-santos    31   31  1,42    17
# 26   2010    Copa Sudamericana               fc-santos     2    2  1,50     -
# 27   2009              Série A               fc-santos    33   33  1,42    10
#
#    Assists own goals Substituted on Substituted off Yellow cards  \
# 0       14         -              -               -            4
# 1        3         -              -               -            2
# 2        -         -              -               -            1
# 3        -         -              -               -            -
# 4        3         -              -               2            3
# 5       15         -              -               2            7
# 6        9         -              -               1            5
# 7        2         -              -               -            2
# 8       17         -              -               1            6
# 9        5         -              -               -            2
# 10       2         -              -               1            1
# 11       -         -              -               3            1
# 12       1         -              -               2            1
# 13       9         -              4               9            6
# 14      10         -              7              11            6
# 15       -         -              -               1            1
# 16       5         -              1               5            1
# 17       -         -              1               -            1
# 18       -         -              -               -            -
# 19       7         -              -               -            6
# 20       -         -              -               -            -
# 21       3         -              -               -            6
# 22       -         -              -               -            -
# 23       5         -              -               1            8
# 24       3         -              -               -            5
# 25       9         -              -               8           11
# 26       1         -              1               -            1
# 27       7         -             19               8            6
#
#    Yellow/red cards Red cards Penalty goals Minutes per goal Minutes played
# 0                 1         -             4              95'         1.797'
# 1                 -         -             -             105'           630'
# 2                 -         -             1             180'           180'
# 3                 -         -             -              45'            90'
# 4                 -         -             2             174'           522'
# 5                 -         1             1             204'         2.653'
# 6                 -         -             1             199'           797'
# 7                 -         -             -             120'           480'
# 8                 -         -             5             127'         3.056'
# 9                 -         -             1             270'           810'
# 10                -         -             -                -            88'
# 11                -         -             -             103'         1.025'
# 12                -         -             -              72'           503'
# 13                -         -             1             117'         2.570'
# 14                -         -             1             193'         1.736'
# 15                -         -             -             206'           206'
# 16                -         -             -             194'           775'
# 17                -         -             -             121'           121'
# 18                -         -             -                -            90'
# 19                -         1             1             107'         1.493'
# 20                -         -             -             180'           180'
# 21                -         -             2             139'         1.110'
# 22                -         -             -             180'           180'
# 23                1         -             4             145'         1.882'
# 24                1         -             -             189'         1.133'
# 25                -         -             4             156'         2.654'
# 26                -         -             -                -           134'
# 27                -         -             -             162'         1.621'

# %%
#del_worksheet("Top FIFA Strikers")
sh=gc.open('Top FIFA Strikers')

sheet_df = sh.sheet1.get_as_df()

#for x in range(len(sheet_df)):
#    wks = sh.worksheet_by_title(str(sheet_df.iloc[x][0]))
#    sh.del_worksheet(wks)

wks = sh.sheet1
player_name_df = pd.DataFrame(player_info[0])
wks.set_dataframe(player_name_df,(1,1))

for x in range(len(player_info[0])):
    wks=sh.add_worksheet(player_info[0][x])
    wks.set_dataframe(frames[player_info[0][x]],(1,1))
